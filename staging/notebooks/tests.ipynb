# %%
# %cd /content/drive/MyDrive/airbnb_project/tests
# Out:
# /content/drive/MyDrive/airbnb_project/tests

# %% [markdown]
# # Transformation test

# %%
import sys
sys.path.append('/content/drive/MyDrive/airbnb_project/src')

# %%
from transformations import format_date

# %%
# !pytest test_transformations.py
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0
# rootdir: /content/drive/MyDrive/airbnb_project/tests
# plugins: anyio-3.7.1, typeguard-4.4.1, langsmith-0.3.0
# collected 3 items
#
# test_transformations.py ...                                                                  [100%]
#
# ======================================== 3 passed in 0.08s =========================================

# %%
# !pytest test_etl_pipeline.py
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0
# rootdir: /content/drive/MyDrive/airbnb_project/tests
# plugins: anyio-3.7.1, typeguard-4.4.1, langsmith-0.3.0
# collected 1 item
#
# test_etl_pipeline.py .                                                                       [100%]
#
# ======================================== 1 passed in 26.59s ========================================
